# %%
# Lab 10 MNIST and NN
import numpy as np
import random
import tensorflow as tf

random.seed(777)  # for reproducibility
learning_rate = 0.001
batch_size = 100
training_epochs = 100
nb_classes = 10
drop_rate = 0.3
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
print(x_train.shape)

x_train = x_train.reshape(x_train.shape[0], 28 * 28)
x_test = x_test.reshape(x_test.shape[0], 28 * 28)

y_train = tf.keras.utils.to_categorical(y_train, nb_classes)
y_test = tf.keras.utils.to_categorical(y_test, nb_classes)

tf.model = tf.keras.Sequential()
# Glorot normal initializer, also called Xavier normal initializer.
# see https://www.tensorflow.org/api_docs/python/tf/initializers

tf.model.add(tf.keras.layers.Dense(input_dim=784, units=512, activation='relu'))
tf.model.add(tf.keras.layers.Dropout(drop_rate))
tf.model.add(tf.keras.layers.Dense(units=512, activation='relu'))
tf.model.add(tf.keras.layers.Dropout(drop_rate))
tf.model.add(tf.keras.layers.Dense(units=512, activation='relu'))
tf.model.add(tf.keras.layers.Dropout(drop_rate))
tf.model.add(tf.keras.layers.Dense(units=512, activation='relu'))
tf.model.add(tf.keras.layers.Dropout(drop_rate))
tf.model.add(tf.keras.layers.Dense(units=nb_classes, activation='softmax'))
tf.model.compile(loss='categorical_crossentropy',
                 optimizer=tf.keras.optimizers.Adam(lr=learning_rate), metrics=['accuracy'])
tf.model.summary()

history = tf.model.fit(x_train, y_train, batch_size=batch_size, epochs=training_epochs)

# predict 10 random hand-writing data
y_predicted = tf.model.predict(x_test)
for x in range(0, 10):
    random_index = random.randint(0, x_test.shape[0]-1)
    print("index: ", random_index,
          "actual y: ", np.argmax(y_test[random_index]),
          "predicted y: ", np.argmax(y_predicted[random_index]))

# evaluate test set
evaluation = tf.model.evaluate(x_test, y_test)
print('loss: ', evaluation[0])
print('accuracy', evaluation[1])
# Out:
# (60000, 28, 28)
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_5 (Dense)              (None, 512)               401920
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 1,195,018
# Trainable params: 1,195,018
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 600/600 [==============================] - 4s 6ms/step - loss: 6.0906 - accuracy: 0.6639
# Epoch 2/100
# 600/600 [==============================] - 3s 6ms/step - loss: 0.3927 - accuracy: 0.8895
# Epoch 3/100
# 600/600 [==============================] - 3s 6ms/step - loss: 0.2762 - accuracy: 0.9226
# Epoch 4/100
# 600/600 [==============================] - 4s 6ms/step - loss: 0.2212 - accuracy: 0.9385
# Epoch 5/100
# 600/600 [==============================] - 3s 6ms/step - loss: 0.2109 - accuracy: 0.9425
# Epoch 6/100
# 600/600 [==============================] - 3s 6ms/step - loss: 0.2032 - accuracy: 0.9453
# Epoch 7/100
# 600/600 [==============================] - 3s 6ms/step - loss: 0.1780 - accuracy: 0.9522
# Epoch 8/100
# 600/600 [==============================] - 3s 6ms/step - loss: 0.1727 - accuracy: 0.9542
# Epoch 9/100
# 600/600 [==============================] - 3s 6ms/step - loss: 0.1822 - accuracy: 0.9554
# Epoch 10/100
# 600/600 [==============================] - 3s 6ms/step - loss: 0.1605 - accuracy: 0.9590
# Epoch 11/100
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1695 - accuracy: 0.9580
# Epoch 12/100
# 600/600 [==============================] - 3s 6ms/step - loss: 0.1642 - accuracy: 0.9584
# Epoch 13/100
# 600/600 [==============================] - 3s 6ms/step - loss: 0.1652 - accuracy: 0.9594
# Epoch 14/100
# 600/600 [==============================] - 3s 6ms/step - loss: 0.1641 - accuracy: 0.9610
# Epoch 15/100
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1729 - accuracy: 0.9586
# Epoch 16/100
# 600/600 [==============================] - 3s 6ms/step - loss: 0.1501 - accuracy: 0.9646
# Epoch 17/100
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1514 - accuracy: 0.9639
# Epoch 18/100
# 600/600 [==============================] - 3s 6ms/step - loss: 0.1511 - accuracy: 0.9658
# Epoch 19/100
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1578 - accuracy: 0.9625
# Epoch 20/100
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1513 - accuracy: 0.9655
# Epoch 21/100
# 600/600 [==============================] - 3s 6ms/step - loss: 0.1447 - accuracy: 0.9667
# Epoch 22/100
# 600/600 [==============================] - 3s 6ms/step - loss: 0.1488 - accuracy: 0.9655
# Epoch 23/100
# 600/600 [==============================] - 3s 6ms/step - loss: 0.1429 - accuracy: 0.9669
# Epoch 24/100
# 600/600 [==============================] - 3s 6ms/step - loss: 0.1497 - accuracy: 0.9660
# Epoch 25/100
# 600/600 [==============================] - 3s 6ms/step - loss: 0.1446 - accuracy: 0.9678
# Epoch 26/100
# 600/600 [==============================] - 3s 6ms/step - loss: 0.1324 - accuracy: 0.9703
# Epoch 27/100
# 600/600 [==============================] - 3s 6ms/step - loss: 0.1585 - accuracy: 0.9651
# Epoch 28/100
# 600/600 [==============================] - 3s 6ms/step - loss: 0.1441 - accuracy: 0.9698
# Epoch 29/100
# 600/600 [==============================] - 3s 6ms/step - loss: 0.1354 - accuracy: 0.9696
# Epoch 30/100
# 600/600 [==============================] - 3s 6ms/step - loss: 0.1567 - accuracy: 0.9668
# Epoch 31/100
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1502 - accuracy: 0.9681
# Epoch 32/100
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1407 - accuracy: 0.9696
# Epoch 33/100
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1230 - accuracy: 0.9713
# Epoch 34/100
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1597 - accuracy: 0.9677
# Epoch 35/100
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1385 - accuracy: 0.9698
# Epoch 36/100
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1385 - accuracy: 0.9699
# Epoch 37/100
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1455 - accuracy: 0.9696
# Epoch 38/100
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1384 - accuracy: 0.9704
# Epoch 39/100
# 600/600 [==============================] - 3s 6ms/step - loss: 0.1289 - accuracy: 0.9713
# Epoch 40/100
# 600/600 [==============================] - 3s 6ms/step - loss: 0.1383 - accuracy: 0.9733
# Epoch 41/100
# 600/600 [==============================] - 3s 6ms/step - loss: 0.1208 - accuracy: 0.9726
# Epoch 42/100
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1293 - accuracy: 0.9713
# Epoch 43/100
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1365 - accuracy: 0.9718
# Epoch 44/100
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1306 - accuracy: 0.9705
# Epoch 45/100
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1524 - accuracy: 0.9697
# Epoch 46/100
# 600/600 [==============================] - 3s 6ms/step - loss: 0.1728 - accuracy: 0.9680
# Epoch 47/100
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1409 - accuracy: 0.9723
# Epoch 48/100
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1058 - accuracy: 0.9765
# Epoch 49/100
# 600/600 [==============================] - 3s 6ms/step - loss: 0.1233 - accuracy: 0.9731
# Epoch 50/100
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1197 - accuracy: 0.9747
# Epoch 51/100
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1610 - accuracy: 0.9667
# Epoch 52/100
# 600/600 [==============================] - 3s 6ms/step - loss: 0.1369 - accuracy: 0.9707
# Epoch 53/100
# 600/600 [==============================] - 3s 6ms/step - loss: 0.1576 - accuracy: 0.9685
# Epoch 54/100
# 600/600 [==============================] - 3s 6ms/step - loss: 0.1332 - accuracy: 0.9701
# Epoch 55/100
# 600/600 [==============================] - 3s 6ms/step - loss: 0.1373 - accuracy: 0.9701
# Epoch 56/100
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1505 - accuracy: 0.9725
# Epoch 57/100
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1416 - accuracy: 0.9701
# Epoch 58/100
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1542 - accuracy: 0.9697
# Epoch 59/100
# 600/600 [==============================] - 3s 6ms/step - loss: 0.1578 - accuracy: 0.9705
# Epoch 60/100
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1333 - accuracy: 0.9720
# Epoch 61/100
# 600/600 [==============================] - 3s 6ms/step - loss: 0.1518 - accuracy: 0.9707
# Epoch 62/100
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1712 - accuracy: 0.9704
# Epoch 63/100
# 600/600 [==============================] - 3s 6ms/step - loss: 0.1475 - accuracy: 0.9724
# Epoch 64/100
# 600/600 [==============================] - 3s 6ms/step - loss: 0.1635 - accuracy: 0.9693
# Epoch 65/100
# 600/600 [==============================] - 3s 6ms/step - loss: 0.1499 - accuracy: 0.9707
# Epoch 66/100
# 600/600 [==============================] - 3s 6ms/step - loss: 0.1424 - accuracy: 0.9735
# Epoch 67/100
# 600/600 [==============================] - 3s 6ms/step - loss: 0.1334 - accuracy: 0.9707
# Epoch 68/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1601 - accuracy: 0.9690
# Epoch 69/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1234 - accuracy: 0.9755
# Epoch 70/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1579 - accuracy: 0.9690
# Epoch 71/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1875 - accuracy: 0.9675
# Epoch 72/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1590 - accuracy: 0.9688
# Epoch 73/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1837 - accuracy: 0.9676
# Epoch 74/100
# 600/600 [==============================] - 3s 6ms/step - loss: 0.1399 - accuracy: 0.9695
# Epoch 75/100
# 600/600 [==============================] - 3s 6ms/step - loss: 0.1447 - accuracy: 0.9708
# Epoch 76/100
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1650 - accuracy: 0.9722
# Epoch 77/100
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1364 - accuracy: 0.9730
# Epoch 78/100
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1515 - accuracy: 0.9704
# Epoch 79/100
# 600/600 [==============================] - 3s 6ms/step - loss: 0.1601 - accuracy: 0.9691
# Epoch 80/100
# 600/600 [==============================] - 3s 6ms/step - loss: 0.1589 - accuracy: 0.9672
# Epoch 81/100
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1445 - accuracy: 0.9705
# Epoch 82/100
# 600/600 [==============================] - 3s 6ms/step - loss: 0.1370 - accuracy: 0.9722
# Epoch 83/100
# 600/600 [==============================] - 3s 6ms/step - loss: 0.1293 - accuracy: 0.9714
# Epoch 84/100
# 600/600 [==============================] - 3s 6ms/step - loss: 0.1566 - accuracy: 0.9719
# Epoch 85/100
# 600/600 [==============================] - 3s 6ms/step - loss: 0.1482 - accuracy: 0.9718
# Epoch 86/100
# 600/600 [==============================] - 3s 6ms/step - loss: 0.1361 - accuracy: 0.9741
# Epoch 87/100
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1424 - accuracy: 0.9689
# Epoch 88/100
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1395 - accuracy: 0.9728
# Epoch 89/100
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1347 - accuracy: 0.9727
# Epoch 90/100
# 600/600 [==============================] - 3s 6ms/step - loss: 0.1565 - accuracy: 0.9681
# Epoch 91/100
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1417 - accuracy: 0.9715
# Epoch 92/100
# 600/600 [==============================] - 4s 6ms/step - loss: 0.2302 - accuracy: 0.9636
# Epoch 93/100
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1729 - accuracy: 0.9625
# Epoch 94/100
# 600/600 [==============================] - 3s 6ms/step - loss: 0.1697 - accuracy: 0.9661
# Epoch 95/100
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1742 - accuracy: 0.9680
# Epoch 96/100
# 600/600 [==============================] - 4s 6ms/step - loss: 0.2159 - accuracy: 0.9670
# Epoch 97/100
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1468 - accuracy: 0.9706
# Epoch 98/100
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1655 - accuracy: 0.9663
# Epoch 99/100
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1530 - accuracy: 0.9695
# Epoch 100/100
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1907 - accuracy: 0.9651
# index:  3757 actual y:  8 predicted y:  8
# index:  7304 actual y:  5 predicted y:  5
# index:  7300 actual y:  7 predicted y:  7
# index:  6039 actual y:  9 predicted y:  9
# index:  9429 actual y:  3 predicted y:  3
# index:  4420 actual y:  5 predicted y:  5
# index:  5507 actual y:  2 predicted y:  2
# index:  8809 actual y:  1 predicted y:  1
# index:  654 actual y:  5 predicted y:  5
# index:  7302 actual y:  8 predicted y:  8
# 313/313 [==============================] - 1s 3ms/step - loss: 0.5036 - accuracy: 0.9764
# loss:  0.5035985112190247
# accuracy 0.9764000177383423
