# %%
# Lab 12 RNN
import numpy as np
import tensorflow as tf

idx2char = ['h', 'i', 'e', 'l', 'o']
# Teach hello: hihell -> ihello
# x_data = [[0, 1, 0, 2, 3, 3]]  # hihell
y_data = [[1, 0, 2, 3, 3, 4]]  # ihello

# Input_shape & HyperParameter
num_classes = 5
input_dim = 5  # one-hot size, same as hidden_size to directly predict one-hot
sequence_length = 6  # |ihello| == 6
learning_rate = 0.1

x_one_hot = np.array([[[1, 0, 0, 0, 0],    # h 0
                       [0, 1, 0, 0, 0],    # i 1
                       [1, 0, 0, 0, 0],    # h 0
                       [0, 0, 1, 0, 0],    # e 2
                       [0, 0, 0, 1, 0],    # l 3
                       [0, 0, 0, 1, 0]]],  # l 3
                     dtype=np.float32)
y_one_hot = tf.keras.utils.to_categorical(y_data, num_classes=num_classes)

print(x_one_hot.shape)
print(y_one_hot.shape)
# Out:
# (1, 6, 5)
# (1, 6, 5)

# %%
tf.model = tf.keras.Sequential()

# make cell and add it to RNN layer
# input_shape = (1,6,5) => number of sequence (batch), length of sequence, size of input dim
cell = tf.keras.layers.SimpleRNNCell(units=num_classes, input_shape=(sequence_length, input_dim))
tf.model.add(tf.keras.layers.RNN(cell=cell, return_sequences=True))

# single LSTM layer can be used as well instead of creating LSTMCell
# tf.model.add(tf.keras.layers.LSTM(units=num_classes, input_shape=(sequence_length, input_dim), return_sequences=True))

# fully connected layer
tf.model.add(tf.keras.layers.TimeDistributed(tf.keras.layers.Dense(units=num_classes, activation='softmax')))

tf.model.compile(loss='categorical_crossentropy', optimizer=tf.keras.optimizers.Adam(lr=learning_rate),
                 metrics=['accuracy'])

# train
tf.model.fit(x_one_hot, y_one_hot, epochs=50)
tf.model.summary()

predictions = tf.model.predict(x_one_hot)
for i, prediction in enumerate(predictions):
    print(prediction)
    # print char using argmax, dict
    result_str = [idx2char[c] for c in np.argmax(prediction, axis=1)]
    print("\tPrediction str: ", ''.join(result_str))
# Out:
# Epoch 1/50
# 1/1 [==============================] - 2s 2s/step - loss: 2.0707 - accuracy: 0.1667
# Epoch 2/50
# 1/1 [==============================] - 0s 33ms/step - loss: 1.5714 - accuracy: 0.1667
# Epoch 3/50
# 1/1 [==============================] - 0s 36ms/step - loss: 1.3466 - accuracy: 0.5000
# Epoch 4/50
# 1/1 [==============================] - 0s 35ms/step - loss: 1.2027 - accuracy: 0.5000
# Epoch 5/50
# 1/1 [==============================] - 0s 31ms/step - loss: 1.0758 - accuracy: 0.5000
# Epoch 6/50
# 1/1 [==============================] - 0s 32ms/step - loss: 0.9662 - accuracy: 0.8333
# Epoch 7/50
# 1/1 [==============================] - 0s 34ms/step - loss: 0.8579 - accuracy: 1.0000
# Epoch 8/50
# 1/1 [==============================] - 0s 31ms/step - loss: 0.7590 - accuracy: 0.8333
# Epoch 9/50
# 1/1 [==============================] - 0s 34ms/step - loss: 0.6638 - accuracy: 0.8333
# Epoch 10/50
# 1/1 [==============================] - 0s 34ms/step - loss: 0.5613 - accuracy: 1.0000
# Epoch 11/50
# 1/1 [==============================] - 0s 33ms/step - loss: 0.4670 - accuracy: 1.0000
# Epoch 12/50
# 1/1 [==============================] - 0s 34ms/step - loss: 0.3816 - accuracy: 1.0000
# Epoch 13/50
# 1/1 [==============================] - 0s 35ms/step - loss: 0.3023 - accuracy: 1.0000
# Epoch 14/50
# 1/1 [==============================] - 0s 35ms/step - loss: 0.2361 - accuracy: 1.0000
# Epoch 15/50
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1844 - accuracy: 1.0000
# Epoch 16/50
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1431 - accuracy: 1.0000
# Epoch 17/50
# 1/1 [==============================] - 0s 31ms/step - loss: 0.1111 - accuracy: 1.0000
# Epoch 18/50
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0874 - accuracy: 1.0000
# Epoch 19/50
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0697 - accuracy: 1.0000
# Epoch 20/50
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0560 - accuracy: 1.0000
# Epoch 21/50
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0452 - accuracy: 1.0000
# Epoch 22/50
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0367 - accuracy: 1.0000
# Epoch 23/50
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0301 - accuracy: 1.0000
# Epoch 24/50
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0250 - accuracy: 1.0000
# Epoch 25/50
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0211 - accuracy: 1.0000
# Epoch 26/50
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0181 - accuracy: 1.0000
# Epoch 27/50
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0158 - accuracy: 1.0000
# Epoch 28/50
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0139 - accuracy: 1.0000
# Epoch 29/50
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0125 - accuracy: 1.0000
# Epoch 30/50
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0112 - accuracy: 1.0000
# Epoch 31/50
# 1/1 [==============================] - 0s 30ms/step - loss: 0.0101 - accuracy: 1.0000
# Epoch 32/50
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0092 - accuracy: 1.0000
# Epoch 33/50
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0084 - accuracy: 1.0000
# Epoch 34/50
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0077 - accuracy: 1.0000
# Epoch 35/50
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0071 - accuracy: 1.0000
# Epoch 36/50
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0066 - accuracy: 1.0000
# Epoch 37/50
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0061 - accuracy: 1.0000
# Epoch 38/50
# 1/1 [==============================] - 0s 30ms/step - loss: 0.0057 - accuracy: 1.0000
# Epoch 39/50
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0054 - accuracy: 1.0000
# Epoch 40/50
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0050 - accuracy: 1.0000
# Epoch 41/50
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0048 - accuracy: 1.0000
# Epoch 42/50
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0045 - accuracy: 1.0000
# Epoch 43/50
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0043 - accuracy: 1.0000
# Epoch 44/50
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0041 - accuracy: 1.0000
# Epoch 45/50
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0039 - accuracy: 1.0000
# Epoch 46/50
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0037 - accuracy: 1.0000
# Epoch 47/50
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0036 - accuracy: 1.0000
# Epoch 48/50
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0035 - accuracy: 1.0000
# Epoch 49/50
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 50/50
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0032 - accuracy: 1.0000
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# rnn (RNN)                    (None, 6, 5)              55
# _________________________________________________________________
# time_distributed (TimeDistri (None, 6, 5)              30
# =================================================================
# Total params: 85
# Trainable params: 85
# Non-trainable params: 0
# _________________________________________________________________
# [[9.52014307e-05 9.96483564e-01 2.72401585e-03 6.32414129e-04
#   6.48526257e-05]
#  [9.95858371e-01 1.57177521e-04 8.82653985e-04 6.97925861e-04
#   2.40388606e-03]
#  [1.23759301e-03 1.18531147e-03 9.97487187e-01 5.77442188e-05
#   3.21423177e-05]
#  [1.34656177e-04 3.91769223e-04 5.45729222e-07 9.97357547e-01
#   2.11542472e-03]
#  [1.07989035e-05 8.93745164e-04 4.60081850e-04 9.98566449e-01
#   6.89651351e-05]
#  [5.20317582e-04 5.62249552e-05 3.05757862e-06 3.95901455e-03
#   9.95461404e-01]]
# 	Prediction str:  ihello
