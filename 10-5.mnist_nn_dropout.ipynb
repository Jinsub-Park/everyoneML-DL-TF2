# %%
# Lab 10 MNIST and NN
import numpy as np
import random
import tensorflow as tf

random.seed(775)  # for reproducibility
learning_rate = 0.001
batch_size = 100
training_epochs = 50
nb_classes = 10
drop_rate = 0.3
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
print(x_train.shape)

x_train = x_train.reshape(x_train.shape[0], 28 * 28)
x_test = x_test.reshape(x_test.shape[0], 28 * 28)

y_train = tf.keras.utils.to_categorical(y_train, nb_classes)
y_test = tf.keras.utils.to_categorical(y_test, nb_classes)

tf.model = tf.keras.Sequential()
# Glorot normal initializer, also called Xavier normal initializer.
# see https://www.tensorflow.org/api_docs/python/tf/initializers

tf.model.add(tf.keras.layers.Dense(input_dim=784, units=512, kernel_initializer='glorot_normal', activation='relu'))
tf.model.add(tf.keras.layers.Dropout(drop_rate))
tf.model.add(tf.keras.layers.Dense(units=512, kernel_initializer='glorot_normal', activation='relu'))
tf.model.add(tf.keras.layers.Dropout(drop_rate))
tf.model.add(tf.keras.layers.Dense(units=512, kernel_initializer='glorot_normal', activation='relu'))
tf.model.add(tf.keras.layers.Dropout(drop_rate))
tf.model.add(tf.keras.layers.Dense(units=512, kernel_initializer='glorot_normal', activation='relu'))
tf.model.add(tf.keras.layers.Dropout(drop_rate))
tf.model.add(tf.keras.layers.Dense(units=nb_classes, kernel_initializer='glorot_normal', activation='softmax'))
tf.model.compile(loss='categorical_crossentropy',
                 optimizer=tf.keras.optimizers.Adam(lr=learning_rate), metrics=['accuracy'])
tf.model.summary()

history = tf.model.fit(x_train, y_train, batch_size=batch_size, epochs=training_epochs)

# predict 10 random hand-writing data
y_predicted = tf.model.predict(x_test)
for x in range(0, 10):
    random_index = random.randint(0, x_test.shape[0]-1)
    print("index: ", random_index,
          "actual y: ", np.argmax(y_test[random_index]),
          "predicted y: ", np.argmax(y_predicted[random_index]))

# evaluate test set
evaluation = tf.model.evaluate(x_test, y_test)
print('loss: ', evaluation[0])
print('accuracy', evaluation[1])
# Out:
# (60000, 28, 28)
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 512)               401920
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 1,195,018
# Trainable params: 1,195,018
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 600/600 [==============================] - 5s 6ms/step - loss: 7.8221 - accuracy: 0.6235
# Epoch 2/50
# 600/600 [==============================] - 3s 6ms/step - loss: 0.4088 - accuracy: 0.8871
# Epoch 3/50
# 600/600 [==============================] - 3s 6ms/step - loss: 0.2745 - accuracy: 0.9236
# Epoch 4/50
# 600/600 [==============================] - 3s 6ms/step - loss: 0.2236 - accuracy: 0.9386
# Epoch 5/50
# 600/600 [==============================] - 3s 6ms/step - loss: 0.2018 - accuracy: 0.9454
# Epoch 6/50
# 600/600 [==============================] - 3s 6ms/step - loss: 0.1868 - accuracy: 0.9492
# Epoch 7/50
# 600/600 [==============================] - 3s 6ms/step - loss: 0.1735 - accuracy: 0.9538
# Epoch 8/50
# 600/600 [==============================] - 3s 6ms/step - loss: 0.1785 - accuracy: 0.9533
# Epoch 9/50
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1819 - accuracy: 0.9536
# Epoch 10/50
# 600/600 [==============================] - 3s 6ms/step - loss: 0.1738 - accuracy: 0.9559
# Epoch 11/50
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1528 - accuracy: 0.9601
# Epoch 12/50
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1772 - accuracy: 0.9582
# Epoch 13/50
# 600/600 [==============================] - 3s 6ms/step - loss: 0.1575 - accuracy: 0.9605
# Epoch 14/50
# 600/600 [==============================] - 3s 6ms/step - loss: 0.1724 - accuracy: 0.9586
# Epoch 15/50
# 600/600 [==============================] - 3s 6ms/step - loss: 0.1420 - accuracy: 0.9659
# Epoch 16/50
# 600/600 [==============================] - 3s 6ms/step - loss: 0.1593 - accuracy: 0.9630
# Epoch 17/50
# 600/600 [==============================] - 3s 6ms/step - loss: 0.1573 - accuracy: 0.9626
# Epoch 18/50
# 600/600 [==============================] - 3s 6ms/step - loss: 0.1577 - accuracy: 0.9640
# Epoch 19/50
# 600/600 [==============================] - 3s 6ms/step - loss: 0.1608 - accuracy: 0.9662
# Epoch 20/50
# 600/600 [==============================] - 3s 6ms/step - loss: 0.1373 - accuracy: 0.9680
# Epoch 21/50
# 600/600 [==============================] - 3s 6ms/step - loss: 0.1391 - accuracy: 0.9683
# Epoch 22/50
# 600/600 [==============================] - 3s 6ms/step - loss: 0.1575 - accuracy: 0.9644
# Epoch 23/50
# 600/600 [==============================] - 3s 6ms/step - loss: 0.1314 - accuracy: 0.9702
# Epoch 24/50
# 600/600 [==============================] - 3s 6ms/step - loss: 0.1452 - accuracy: 0.9686
# Epoch 25/50
# 600/600 [==============================] - 3s 6ms/step - loss: 0.1393 - accuracy: 0.9688
# Epoch 26/50
# 600/600 [==============================] - 3s 6ms/step - loss: 0.1609 - accuracy: 0.9660
# Epoch 27/50
# 600/600 [==============================] - 3s 6ms/step - loss: 0.1463 - accuracy: 0.9682
# Epoch 28/50
# 600/600 [==============================] - 3s 6ms/step - loss: 0.1257 - accuracy: 0.9713
# Epoch 29/50
# 600/600 [==============================] - 3s 6ms/step - loss: 0.1443 - accuracy: 0.9688
# Epoch 30/50
# 600/600 [==============================] - 3s 6ms/step - loss: 0.1272 - accuracy: 0.9715
# Epoch 31/50
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1515 - accuracy: 0.9659
# Epoch 32/50
# 600/600 [==============================] - 3s 6ms/step - loss: 0.1329 - accuracy: 0.9707
# Epoch 33/50
# 600/600 [==============================] - 3s 6ms/step - loss: 0.1534 - accuracy: 0.9698
# Epoch 34/50
# 600/600 [==============================] - 3s 6ms/step - loss: 0.1262 - accuracy: 0.9715
# Epoch 35/50
# 600/600 [==============================] - 3s 6ms/step - loss: 0.1425 - accuracy: 0.9684
# Epoch 36/50
# 600/600 [==============================] - 3s 6ms/step - loss: 0.1393 - accuracy: 0.9713
# Epoch 37/50
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1664 - accuracy: 0.9677
# Epoch 38/50
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1352 - accuracy: 0.9698
# Epoch 39/50
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1261 - accuracy: 0.9730
# Epoch 40/50
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1524 - accuracy: 0.9690
# Epoch 41/50
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1393 - accuracy: 0.9709
# Epoch 42/50
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1384 - accuracy: 0.9722
# Epoch 43/50
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1330 - accuracy: 0.9719
# Epoch 44/50
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1467 - accuracy: 0.9704
# Epoch 45/50
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1318 - accuracy: 0.9712
# Epoch 46/50
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1290 - accuracy: 0.9716
# Epoch 47/50
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1350 - accuracy: 0.9706
# Epoch 48/50
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1584 - accuracy: 0.9682
# Epoch 49/50
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1238 - accuracy: 0.9737
# Epoch 50/50
# 600/600 [==============================] - 3s 6ms/step - loss: 0.1702 - accuracy: 0.9666
# index:  7967 actual y:  0 predicted y:  0
# index:  353 actual y:  6 predicted y:  6
# index:  2684 actual y:  3 predicted y:  3
# index:  7121 actual y:  8 predicted y:  8
# index:  6867 actual y:  4 predicted y:  4
# index:  324 actual y:  0 predicted y:  0
# index:  137 actual y:  1 predicted y:  1
# index:  2050 actual y:  8 predicted y:  8
# index:  5221 actual y:  6 predicted y:  6
# index:  9841 actual y:  5 predicted y:  5
# 313/313 [==============================] - 1s 4ms/step - loss: 0.2017 - accuracy: 0.9778
# loss:  0.20170269906520844
# accuracy 0.9778000116348267
