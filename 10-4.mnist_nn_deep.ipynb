# %%
# Lab 10 MNIST and NN
import numpy as np
import random
import tensorflow as tf

random.seed(777)  # for reproducibility
learning_rate = 0.001
batch_size = 100
training_epochs = 50
nb_classes = 10

(x_train, y_train), (x_test2, y_test) = tf.keras.datasets.mnist.load_data()
print(x_train.shape)

x_train = x_train.reshape(x_train.shape[0], 28 * 28)
x_test = x_test2.reshape(x_test2.shape[0], 28 * 28)

y_train = tf.keras.utils.to_categorical(y_train, nb_classes)
y_test = tf.keras.utils.to_categorical(y_test, nb_classes)

tf.model = tf.keras.Sequential()
# Glorot normal initializer, also called Xavier normal initializer.
# see https://www.tensorflow.org/api_docs/python/tf/initializers

tf.model.add(tf.keras.layers.Dense(input_dim=784, units=512, kernel_initializer='glorot_normal', activation='relu'))
tf.model.add(tf.keras.layers.Dense(units=512, kernel_initializer='glorot_normal', activation='relu'))
tf.model.add(tf.keras.layers.Dense(units=512, kernel_initializer='glorot_normal', activation='relu'))
tf.model.add(tf.keras.layers.Dense(units=512, kernel_initializer='glorot_normal', activation='relu'))
tf.model.add(tf.keras.layers.Dense(units=nb_classes, kernel_initializer='glorot_normal', activation='softmax'))
tf.model.compile(loss='categorical_crossentropy',
                 optimizer=tf.keras.optimizers.Adam(lr=learning_rate), metrics=['accuracy'])
tf.model.summary()

history = tf.model.fit(x_train, y_train, batch_size=batch_size, epochs=training_epochs)

# predict 10 random hand-writing data
y_predicted = tf.model.predict(x_test)
for x in range(0, 10):
    random_index = random.randint(0, x_test.shape[0]-1)
    print("index: ", random_index,
          "actual y: ", np.argmax(y_test[random_index]),
          "predicted y: ", np.argmax(y_predicted[random_index]))

# evaluate test set
evaluation = tf.model.evaluate(x_test, y_test)
print('loss: ', evaluation[0])
print('accuracy', evaluation[1])
# Out:
# (60000, 28, 28)
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 512)               401920
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 1,195,018
# Trainable params: 1,195,018
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 600/600 [==============================] - 10s 15ms/step - loss: 3.3229 - accuracy: 0.8329
# Epoch 2/50
# 600/600 [==============================] - 8s 13ms/step - loss: 0.1386 - accuracy: 0.9581
# Epoch 3/50
# 600/600 [==============================] - 8s 14ms/step - loss: 0.0999 - accuracy: 0.9696
# Epoch 4/50
# 600/600 [==============================] - 10s 17ms/step - loss: 0.0880 - accuracy: 0.9735
# Epoch 5/50
# 600/600 [==============================] - 5s 8ms/step - loss: 0.0773 - accuracy: 0.9762
# Epoch 6/50
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0618 - accuracy: 0.9812
# Epoch 7/50
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0687 - accuracy: 0.9803
# Epoch 8/50
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0571 - accuracy: 0.9829
# Epoch 9/50
# 600/600 [==============================] - 3s 6ms/step - loss: 0.0478 - accuracy: 0.9858
# Epoch 10/50
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0486 - accuracy: 0.9866
# Epoch 11/50
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0513 - accuracy: 0.9856
# Epoch 12/50
# 600/600 [==============================] - 3s 6ms/step - loss: 0.0492 - accuracy: 0.9859
# Epoch 13/50
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0482 - accuracy: 0.9864
# Epoch 14/50
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0441 - accuracy: 0.9886
# Epoch 15/50
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0442 - accuracy: 0.9895
# Epoch 16/50
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0304 - accuracy: 0.9919
# Epoch 17/50
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0321 - accuracy: 0.9924
# Epoch 18/50
# 600/600 [==============================] - 13s 21ms/step - loss: 0.0327 - accuracy: 0.9914
# Epoch 19/50
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0413 - accuracy: 0.9902
# Epoch 20/50
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0278 - accuracy: 0.9937
# Epoch 21/50
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0364 - accuracy: 0.9912
# Epoch 22/50
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0319 - accuracy: 0.9925
# Epoch 23/50
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0271 - accuracy: 0.9938
# Epoch 24/50
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0218 - accuracy: 0.9945
# Epoch 25/50
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0282 - accuracy: 0.9934
# Epoch 26/50
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0262 - accuracy: 0.9939
# Epoch 27/50
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0235 - accuracy: 0.9945
# Epoch 28/50
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0201 - accuracy: 0.9955
# Epoch 29/50
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0350 - accuracy: 0.9923
# Epoch 30/50
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0181 - accuracy: 0.9956
# Epoch 31/50
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0142 - accuracy: 0.9966
# Epoch 32/50
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0236 - accuracy: 0.9951
# Epoch 33/50
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0172 - accuracy: 0.9964
# Epoch 34/50
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0241 - accuracy: 0.9952
# Epoch 35/50
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0164 - accuracy: 0.9968
# Epoch 36/50
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0221 - accuracy: 0.9958
# Epoch 37/50
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0169 - accuracy: 0.9968
# Epoch 38/50
# 600/600 [==============================] - 3s 4ms/step - loss: 0.0168 - accuracy: 0.9959
# Epoch 39/50
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0138 - accuracy: 0.9972
# Epoch 40/50
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0136 - accuracy: 0.9973
# Epoch 41/50
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0130 - accuracy: 0.9972
# Epoch 42/50
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0233 - accuracy: 0.9957
# Epoch 43/50
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0240 - accuracy: 0.9950
# Epoch 44/50
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0173 - accuracy: 0.9973
# Epoch 45/50
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0200 - accuracy: 0.9975
# Epoch 46/50
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0134 - accuracy: 0.9977
# Epoch 47/50
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0331 - accuracy: 0.9953
# Epoch 48/50
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0272 - accuracy: 0.9956
# Epoch 49/50
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0138 - accuracy: 0.9972
# Epoch 50/50
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0116 - accuracy: 0.9972
# index:  3757 actual y:  8 predicted y:  8
# index:  7304 actual y:  5 predicted y:  5
# index:  7300 actual y:  7 predicted y:  7
# index:  6039 actual y:  9 predicted y:  9
# index:  9429 actual y:  3 predicted y:  3
# index:  4420 actual y:  5 predicted y:  5
# index:  5507 actual y:  2 predicted y:  2
# index:  8809 actual y:  1 predicted y:  1
# index:  654 actual y:  5 predicted y:  5
# index:  7302 actual y:  8 predicted y:  8
# 313/313 [==============================] - 1s 3ms/step - loss: 0.2141 - accuracy: 0.9776
# loss:  0.21405437588691711
# accuracy 0.9775999784469604
